# %%
def simple_gcd(a,b):
  if a < b:
    a, b = b, a
  x = b
  while True:
    if a % x == 0 and b % x == 0:
      return x
    else: x -= 1

# %%
simple_gcd(100,80)
# Out:
# 20

# %%
simple_gcd(234723,23523)
# Out:
# 3
